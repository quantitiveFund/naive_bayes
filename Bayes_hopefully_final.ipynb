# %% [markdown]
# # 贝叶斯决策论和朴素贝叶斯分类器
#
# 徐迪深 浙江工商大学 金融学院 CFA1901

# %% [markdown]
# ## 贝叶斯决策论
#
# ​周末和朋友在一个大型商业综合体逛街吃饭，选择太多了，去吃什么好呢？好朋友聚在一起不容易，因此吃饭的选择会比较重要。如何选择呢？大家会提出各自建议：选一个口味符合的，选一个装修漂亮的，选一个生意兴旺的，选一个在美团上有很多介绍的，选一个有朋友去过的，诸如此类的建议你肯定需要尽可能的采纳，而且希望得到一个完美的交集。但是显然把所有的建议都遍历一遍的话，估计大家都不等不到吃饭了，而且你能找到收集全所有的建议吗？显然不能。但是选择还是要做的，饭总归要吃的。因此我们的决策是**基于一个不完备的信息集的**。此外，我们的决策过程是将有效的建议，一个一个根据重要性来尝试的，比如，我们认为一个好的餐馆，第一个也是最重要的特征是在网络平台上有好口碑，第二个次重要的特征是当天的生意好、客人多，第三重要的是我们当中有人去过的...... **我们的决策是一个不断的，但同时是有序的数据采集和信息分析的过程**。
#
# 我们知道生活中绝大多数决策面临的信息都是不全的，我们只有有限的信息。在无法得到全面的信息的情况下，我们就在信息有限的情况下，尽可能做出一个好的预测。这个每天都在进行的过程就是大名鼎鼎的贝叶斯理论(Bayes theorem)，或者是贝叶斯推断(Bayes inference)，贝叶斯法则(Bayes rule).

# %% [markdown]
# 现在可以设想一个场景。
#
# 假如你想要去学校附近的宝龙广场的一个餐馆a吃饭。你去查看了网络上对这家餐馆的介绍，比如口味，装修，去的人多不多，想根据这些信息判断这个餐馆好不好。那么在贝叶斯决策论中，我们将诸如**口味，装修，客流量**这些信息称为特征，而餐馆**好**和**不好**称为类别。
#
# 一个餐馆的口味，装修，去的人多不多都是餐馆的公开信息。那么基于这些信息，餐馆a是好餐馆（不好的餐馆也一样）的概率可以用条件概率表示：
#
# $$
# P(好餐馆|口味，装修，客流量)\qquad(1)
# $$
#
# $(1)$式可以用贝叶斯公式展开，有
#
# $$
# P(好餐馆|口味，装修，客人的多少)=P(好餐馆)\frac{P(口味，装修，客流量|好餐馆)}{P(口味，装修，客流量)}\qquad(2)
# $$

# %% [markdown]
# 显然我们希望$(1)$能越大越好。
#
# 而将$(1)$得到$(2)$之后，可以发现$𝑃(好餐馆)$（我们也称为先验（prior）概率）是一个固定的值，同理，$P(口味，装修，客人的多少)$也是常数。在实际计算中，我们可以根据大数定理，用频率来估计概率。
#
# 所以当$𝑃(口味，装修，客人的多少|好餐馆)$最大时，$(1)$也会最大。$𝑃(口味，装修，客流量|好餐馆)$这个我们叫做似然（likelihood）概率。而最大化似然概率我们最常用的就是极大似然估计。
#
# $(2)$也给了我们一个启示：
#
# $$
# \frac{P(口味，装修，客人的多少|好餐馆)}{P(口味，装修，客流量)}\qquad(3)
# $$
#
# 假如$(3)$能够大于1，就意味着比起我们的总体样本，那就意味着这一类餐馆更有可能是好餐馆。

# %% [markdown]
# ### 极大似然估计
#
# 回到上面一节我们的思路：想要$P(好餐馆|口味，装修，客人的多少)$更大，那么$P(口味，装修，客人的多少|好餐馆)$就要更大
#
# 现在的问题是如何最大化似然概率。我们常用的方法就是极大似然估计。
#
# 以极大似然估计$P(口味，装修，客人的多少|好餐馆)$为例。
#
# 现在你在网上看到了N个人对于餐馆的评论，我们对每个人标记为$x_i$($i \in N$),其中$x_i$={$口味=偏咸/偏甜，装修=豪华/简单，客流量=多/少$}，以及每个人的评价$y_i$={$好/不好$}（$i \in N$）
#
# 那么，就可以由这些人的评论得到如下一组概率
#
# $$
# P([口味=偏甜/偏咸，装修=豪华/简单，客流量=多/少]的各种情况的组合|y=好餐馆)
# $$
#
# 实际上最后就是想找到一个最符合好餐厅的特征（例如我喜欢口味偏咸，装修简单，客流量少的餐厅，那么对于我来说$P(口味=咸，装修=简单，客流量=少|好参观)$这个概率就是最大的似然概率）

# %% [markdown]
# ## 朴素贝叶斯分类器
#
# 贝叶斯分类器有很多种，而朴素贝叶斯分类器是在所有特征都独立的假设进行分类的一种算法。至于为什么要做独立的假设（往往这个假设并不符合实际），是因为独立的假设使得计算简单很多，而对于预测的准确程度又不会损失到不能接受的程度。
#
# 那么，上面的$(2)$式就可以写成
#
# $$
# P(好餐馆|口味，装修，客人的多少)=P(好餐馆)\frac{P(口味|好餐馆)P(装修|好餐馆)P(客流量|好餐馆)}{P(口味)P(装修)P(客流量)}\qquad(5)
# $$
#
# 这样比起原来的式子，明显计算方面简单许多。但是，贝叶斯分类器也并不是只有朴素贝叶斯分类器一种，还有一类半朴素贝叶斯分类器，相对朴素的假设则放宽了许多，精度提高的同时计算也更加复杂。分类器的选用具体要根据任务的要求和背景决定

# %% [markdown]
# ### 拉普拉斯修正
#
# 有时候我们会遇到这样的情况。
#
# 还是以判断餐馆a的好坏为例：你现在拿到了网上各个网友对餐馆a的口味，装修，客流量和对餐馆a的评价（好或者不好），但是你还多关注了一个特征：是否有音乐。但网上评价的人并不在意这个，所以没有人提起这个餐馆有没有音乐。于是有一个特征的特征值都缺失了。那么你在具体计算先验概率和似然概率甚至在计算贝叶斯公式中的分母（$P(音乐)$）的时候，这个概率为0（但分母肯定不可以为0）。
#
# 你可以选择丢弃这个特征。但是你仍然很在意这个餐厅是否有音乐，所以并不想丢弃，那么该如何解决这个问题？
#
# 拉普拉斯修正就是一个解决方法。
#
# 拉普拉斯修正核心要保证的点是两个：第一个是让计算不违背数学的基本规律，第二个是不能让修正后的概率和修正之前有不可接受的差异（比如修正前我们的$P(音乐)$为0但修正后突然增加到0.8，这样会使得结果产生重大误差。）
#
# 具体做法如下：
#
# 还是以我们上面要判断餐馆a的好坏为例。其实在你的训练样本足够大的情况下，我们原来的对音乐取餐厅好坏的条件的似然概率计算是这样的：
#
# $$
# P(音乐=有|餐厅=好)=\frac{有音乐且为好餐厅的个数=0}{好餐厅的个数}=0
# $$
#
# 那么拉普拉斯修正就可以这样修正：
#
# $$
# P'(音乐=有|餐厅=好)=\frac{有音乐且为好餐厅的个数+1}{好餐厅的个数+音乐这个特征的取值（有/无，所以是2）}\neq 0
# $$
#
# 然而拉普拉斯修正还不能改变信息集本身的特点。举个例子，假如你没有做拉普拉斯修正之前，你调查到的信息表示宝龙广场的特点是口味偏咸，装修简单，客流量大和没有音乐的餐馆更有可能是好餐馆，然而修正之后信息反应的是口味偏甜，装修豪华的，客流量小且有音乐的餐馆更有可能是好餐馆，那么显然这个修正是一个很失败的修正。
#
# 所以既然上面音乐对餐厅好坏取条件的似然概率做了修正，那么其它特征都要相应做修正。
#
# 先验概率的修正：
# $$
# P'(餐厅=好)=\frac{好餐厅的个数+1}{所有餐厅的个数+所有特征的个数（口味，装修，客流量，音乐所以总共4个）}
# $$
#
# 似然概率的修正，以口味的似然概率为例：
#
# $$
# P'(口味=偏咸|餐厅=好)=\frac{口味偏咸且是好餐厅的个数+1}{好餐厅的个数+口味这个特征可能取值的个数（偏咸/偏甜，所以是2）}
# $$
#
# 这样就能保证不舍弃音乐这个特征，且不改变原来训练样本（经验）的信息情况下，对目标进行分类（预测）

# %% [markdown]
# 在网络上有很多相关的视频，可以帮助理解贝叶斯地的意义
#
# https://www.bilibili.com/video/BV1wf4y1d7iU?from=search&seid=16834708435849129354

# %% [markdown]
# ## 贝叶斯分类器在金融的应用：信息分类

# %% [markdown]
# 贝叶斯本身有许多实际应用: 垃圾邮件分类，搜索引擎中的推荐顺序等等。
#
# 在金融实践中，贝叶斯分类器算法在处理一些非数字类信息和离散信息的优势被广泛应用，比如贷款者的信用评估，投资者风险偏好的评估，以及下面提到的信息的筛选

# %%
pd.read_excel('data_sina_fin_news2.xlsx').head()
#展示数据
# Out:
#                                                   内容  标签
# 0  【摩根大通：MSCI本次指数调整料为中国带来71亿美元被动流入】摩根大通报告称，在MSCI将...  关注
# 1  【统计局：2018年城镇单位就业人员平均工资较快增长】国家统计局今天发布了2018年平均工资...  关注
# 2   【商务部：中国提交关于世贸组织改革的建议文件】商务部消息，5月13日，中国向世界贸易组织正...  关注
# 3  高通和HMD Global签订5G多模全球专利许可协议，将加快HMD Global的诺基亚品...  关注
# 4                                大智慧快速拉升封涨停，封单近60万手。  关注

# %% [markdown]
# 上面给出的是从新浪网上爬下来的的新闻，同时旁边附有标签。下面是对于该训练的样本的朴素贝叶斯分类器的伪代码

# %% [markdown]
#     import pandas as pd
#     import jieba
#     import re
#
#     输入：训练集dataframe，测试集dataframe
#
#     过程：
#     计算训练样本中有多少被标为关注，记为focus，同理标为其他的样本数为ignore，训练样本总和为total
#     用jieba和re包处理每一个样本，得到每一条新闻的关键词列表[word1,word2,...],同时该训练用的样本标签为tag
#     建立一个字典keyword_freq，键是每一个关键词，值是一个字典{focus:0,ignore:0}
#     for word in [word1,word2,...] do
#       if word in key_word_freq then
#         if tag = 关注 then
#           keyword_freq[word][focus] += 1
#         else
#           keyword_freq[word][ignore] += 1
#       else(还没有遇到该关键词的情况需要添加)
#         if tag = 关注 then
#           keyword_freq[word] = {focus：1，ignore：0}
#         else
#           keyword_freq[word] = {focus：0，ignore：1}
#      end for
#      预测一条未知信息
#      输入：未知的一条新闻
#      过程：
#      用jieba和re按上面同样方法处理信息，得到关键词列表[key1,key2,key3,...]
#      for key in [key1,key2,key3,...] do
#        计算P（关注）= focus/toal，P(其他) = ignore/total
#        if key in keyword_freq then
#         标签为关注的判别值 = P（关注）*= P(key|关注) = keyword_freq.get(key)[focus]/keyword_freq.get(key)
#         标签为其他的判别值 = P（其他）*= P(key|其他) = keyword_freq.get(key)[ignore]/keyword_freq.get(key)
#        else
#         所有判别值×1
#      输出：
#      最大的判别值所对应的标签

# %%
import pandas as pd
import jieba
import re

class news(object):
    def __init__(self):
        self.stats = {'focus': 0, 'ignore': 0, 'total': 0}#focus代表需要关注的信息数，ignore代表可以忽略的信息数，total是总和
        self.keyword_freq = {}  
        self.r = '[在从的得地多个百千万亿A-Za-z0-9_.!+-=——,$%^，。？、~@#￥%……&*：《》<>「」{}【】()/]'#这里我们需要去掉一些我们不需要的字符

    def split(self,line):#将一串中文字符串分割成词，并放入列表当中
        return jieba.lcut(line)
    
    def ProcessLine(self,massage):#这里的处理是将字符串中非中文以及一些常用的没有实际意义的助词介词去掉
        return re.sub(self.r,'',massage)
    
    def add_keyword_freq(self, news, tag):        
        for char in self.split(self.ProcessLine(news)):#遍历新闻中的所有关键词
            if char in self.keyword_freq.keys():#如果关键词被记录了那么就在对应的标签计数
                if tag == '关注':
                    self.keyword_freq[str(char)]['focus'] += 1
                else:
                    self.keyword_freq[str(char)]['ignore'] += 1
            else: # 如果该名字没有被记录，则增加键值
                if tag == '关注':
                    self.keyword_freq[str(char)]={'focus':1, 'ignore':0}
                else:
                    self.keyword_freq[str(char)]={'focus':0, 'ignore':1}
        
    def load_data(self, ndata): 
        for index, row in ndata.iterrows():
            self.add_keyword_freq(row[0],row[1])#对每条新闻进行记录
            if row[1] == '关注':
                self.stats['focus'] += 1#记录各个标签的数目
            else:
                self.stats['ignore'] += 1
        self.stats['total'] = self.stats['focus'] + self.stats['ignore']
                
        
    def estimate_news(self, line, tag = 'focus'):   # Input name and predicted gender, return a precentage     
        '''
        贝叶斯公式: P(Y|X) = P(X|Y) * P(Y) / P(X)
        当X条件独立时, P(X|Y) = P(X1|Y) * P(X2|Y) * ...
        P（Y） 男或者女的概率， 因为名字非男即女，因此就默认成男人的概率。
        X1，X2是名字中的每一个字。
        /P(X) 该项是归一项，暂时不做考虑，不影响对男女名的判断，但是影响输出是否为一个0-1之间的概率
        P(X1|Y)P(X2|Y)P(Y) is needed to be compared with different Y (genders)
        '''
        # prob 为先验概率
        prob = self.stats['focus']/self.stats['total'] if tag == 'focus' \
        else self.stats['ignore']/self.stats['total'] # 根据所有样本来确定先验概率
        prob = 0.5  # 简单设定先验概率
        
        for char in self.split(self.ProcessLine(line)): # 遍历名字中的每一个字，认为每一个字是独立的，此处忽略了名字是一个有意义的词语的情况
            if str(char) in self.keyword_freq: # 正常情况，该名字出现过，有过统计
                prob *= self.keyword_freq.get(str(char))[str(tag)] / self.stats.get(str(tag))
            else:
                print('Oops! %s (%s) has not been covered by our training data.'% (char,line))
                # 概率乘以1，表示没有贡献，忽略该关键词的影响
                prob *= 1
        return prob
    
    def check_news(self, news, display = 1):
        # 由于未考虑归一项，即 prob_f + prob_m 可能不等于 1，因此需要都做一遍
        prob_f = self.estimate_news(news, 'focus')
        prob_i = self.estimate_news(news, 'ignore')

        if display == 1:
            if prob_f > prob_i:
                print('%s should raise attention with confidence level of %s'.format(news, round(1. * prob_f / (prob_i + prob_f),2)))
            else:
                print('%s should ignored with confidence level of %s'.format(news, round(1. * prob_i / (prob_i+ prob_f),2)))
        else:
            # 通过比标签为关注的概率和标签为其他的概率的大小来判断是男人还是女人名字
            if prob_i > prob_f:
                return 'ignore'
            elif prob_i <= prob_f:
                return 'focus'
    
    def data_split(self, data, f, i):
        # 将数据分为两个部分，训练和测试。 m是给男人留的测试数量，f是给女人名留的测试数量
        test = pd.concat([data[data['标签']=='关注'][:f],data[data['标签']=='其他'][:i]],ignore_index=True)
        train = pd.concat([data[data['标签']=='关注'][f:],data[data['标签']=='其他'][i:]],ignore_index=True)
        return train, test
    
    def testing(self,test, f, i):
        self.test_res = {'ii':0, 'ff':0, 'if':0, 'fi':0, 'focus': f, 'ignore': i}
        for index, row in test.iterrows():
            res = self.check_news(row[0], display = 0)
            if res == 'focus' and row[1] == '关注':
                self.test_res['ff'] += 1
            elif res == 'focus' and row[1] == '其他':
                self.test_res['fi'] += 1
            elif res == 'ignore' and row[1] == '其他':
                self.test_res['ii'] += 1
            elif res == 'ignore' and row[1] == '关注':
                self.test_res['if'] += 1
        print('正确率: 重点信息被关注: %s, 无关信息被忽略: %s, 错误率： 重点信息被忽略: %s, 无关信息被关注: %s.' %\
              (self.test_res['ff']/self.test_res['focus'], self.test_res['ii']/self.test_res['ignore'],self.test_res['if']/self.test_res['ignore'],self.test_res['fi']/self.test_res['focus']))

import time
def dur(op=None, clock=[time.time()]):
  if op != None:
    duration = time.time() - clock[0]
    print('%s finished. Duration %.2f seconds.' % (op, duration))
  clock[0] = time.time()
  
if __name__ == '__main__':
    check = news()
    data = pd.read_excel('data_sina_fin_news2.xlsx')
    i = 500
    f = 500
    train, test = check.data_split(data, f, i)
    #------- Trainning 
    dur()
    check.load_data(train)
    dur('Gender learning')
    #--------Testing by testing data
    dur()
    check.testing(test, f, i)
    dur('Gender Testing')
    # ------ Use your own data
    #check.check_news(input('请在冒号后输入一条你想测试的新闻：'))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\EDWARD~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.669 seconds.
# Prefix dict has been built successfully.
# Gender learning finished. Duration 6.44 seconds.
# Oops! 注将 (【摩根大通：MSCI本次指数调整料为中国带来71亿美元被动流入】摩根大通报告称，在MSCI将指数调整后，预计将为中国带来123亿美元的被动资金流，其中包括71亿美元流入以及52亿美元流出。在100%纳入后，预计将触发总计760亿美元被动资金流入。注：MSCI将指数中的中国A股大盘股纳入因子从5%增加至10%，并直接以10%的纳入因子纳入中国创业板大盘股。) has not been covered by our training data.
# Oops! 注将 (【摩根大通：MSCI本次指数调整料为中国带来71亿美元被动流入】摩根大通报告称，在MSCI将指数调整后，预计将为中国带来123亿美元的被动资金流，其中包括71亿美元流入以及52亿美元流出。在100%纳入后，预计将触发总计760亿美元被动资金流入。注：MSCI将指数中的中国A股大盘股纳入因子从5%增加至10%，并直接以10%的纳入因子纳入中国创业板大盘股。) has not been covered by our training data.
# Oops! 超创 (小米集团一度跌超5%，创今年2月以来最低。) has not been covered by our training data.
# Oops! 超创 (小米集团一度跌超5%，创今年2月以来最低。) has not been covered by our training data.
# Oops! 绿庭 (创投概念股走强，复旦复华涨停，华控赛格、市北高新、张江高科、鲁信创投、民丰特纸、大众公用、绿庭投资、九鼎投资等个股集体拉升走强。) has not been covered by our training data.
# Oops! 绿庭 (创投概念股走强，复旦复华涨停，华控赛格、市北高新、张江高科、鲁信创投、民丰特纸、大众公用、绿庭投资、九鼎投资等个股集体拉升走强。) has not been covered by our training data.
# Oops! 抓紧抓好 (【海口启动建筑设计改革创新试点工作】日前，住房和城乡建设部把海口市列入开展“彰显城市特色、践行绿色理念”建筑设计改革创新试点城市。5月13日晚，海口召开“彰显城市特色、践行绿色理念”建筑设计改革创新试点工作座谈会，标志着海口正式启动该项试点工作。会议指出，海口将立足为全国城市规划建设管理探索经验的全局高度，全力以赴把试点工作抓紧抓好抓出成效，为破解“千城一面”难题探索可复制可推广的经验。（海南日报）) has not been covered by our training data.
# Oops! 抓紧抓好 (【海口启动建筑设计改革创新试点工作】日前，住房和城乡建设部把海口市列入开展“彰显城市特色、践行绿色理念”建筑设计改革创新试点城市。5月13日晚，海口召开“彰显城市特色、践行绿色理念”建筑设计改革创新试点工作座谈会，标志着海口正式启动该项试点工作。会议指出，海口将立足为全国城市规划建设管理探索经验的全局高度，全力以赴把试点工作抓紧抓好抓出成效，为破解“千城一面”难题探索可复制可推广的经验。（海南日报）) has not been covered by our training data.
# Oops! 核燃料 (【中核集团具备华龙一号燃料元件批量化制造能力】国资委官网消息，近日，我国三代核电华龙一号燃料元件——中核集团自主研制的CF3核燃料元件成功完成批量化制造，通过了在中核建中进行的出厂验收。这标志着中核集团具备了CF系列又一新型核燃料元件批量化制造的能力，进一步增强了在核燃料领域的核心竞争力，将为华龙一号“走出去”提供强力支撑。) has not been covered by our training data.
# Oops! 核燃料 (【中核集团具备华龙一号燃料元件批量化制造能力】国资委官网消息，近日，我国三代核电华龙一号燃料元件——中核集团自主研制的CF3核燃料元件成功完成批量化制造，通过了在中核建中进行的出厂验收。这标志着中核集团具备了CF系列又一新型核燃料元件批量化制造的能力，进一步增强了在核燃料领域的核心竞争力，将为华龙一号“走出去”提供强力支撑。) has not been covered by our training data.
# Oops! 核燃料 (【中核集团具备华龙一号燃料元件批量化制造能力】国资委官网消息，近日，我国三代核电华龙一号燃料元件——中核集团自主研制的CF3核燃料元件成功完成批量化制造，通过了在中核建中进行的出厂验收。这标志着中核集团具备了CF系列又一新型核燃料元件批量化制造的能力，进一步增强了在核燃料领域的核心竞争力，将为华龙一号“走出去”提供强力支撑。) has not been covered by our training data.
# Oops! 六板 (【丰乐种业“七日六板”】丰乐种业早盘再度强势封板，收获七个交易日以来的第六个涨停。) has not been covered by our training data.
# Oops! 亚联 (5G板块异动拉升，奥维通信、吴通控股强势封板，亚联发展、富通鑫茂、宜通世纪、汇源通信、吉大通信、中新赛克、法尔胜等均有上涨。消息面，据媒体援引业内人士预计，5G临时牌照有望在本周世界电信日期间发出。5月17日是世界电信日。) has not been covered by our training data.
# Oops! 富通 (5G板块异动拉升，奥维通信、吴通控股强势封板，亚联发展、富通鑫茂、宜通世纪、汇源通信、吉大通信、中新赛克、法尔胜等均有上涨。消息面，据媒体援引业内人士预计，5G临时牌照有望在本周世界电信日期间发出。5月17日是世界电信日。) has not been covered by our training data.
# Oops! 鑫茂 (5G板块异动拉升，奥维通信、吴通控股强势封板，亚联发展、富通鑫茂、宜通世纪、汇源通信、吉大通信、中新赛克、法尔胜等均有上涨。消息面，据媒体援引业内人士预计，5G临时牌照有望在本周世界电信日期间发出。5月17日是世界电信日。) has not been covered by our training data.
# Oops! 吉大 (5G板块异动拉升，奥维通信、吴通控股强势封板，亚联发展、富通鑫茂、宜通世纪、汇源通信、吉大通信、中新赛克、法尔胜等均有上涨。消息面，据媒体援引业内人士预计，5G临时牌照有望在本周世界电信日期间发出。5月17日是世界电信日。) has not been covered by our training data.
# Oops! 赛克 (5G板块异动拉升，奥维通信、吴通控股强势封板，亚联发展、富通鑫茂、宜通世纪、汇源通信、吉大通信、中新赛克、法尔胜等均有上涨。消息面，据媒体援引业内人士预计，5G临时牌照有望在本周世界电信日期间发出。5月17日是世界电信日。) has not been covered by our training data.
# Oops! 亚联 (5G板块异动拉升，奥维通信、吴通控股强势封板，亚联发展、富通鑫茂、宜通世纪、汇源通信、吉大通信、中新赛克、法尔胜等均有上涨。消息面，据媒体援引业内人士预计，5G临时牌照有望在本周世界电信日期间发出。5月17日是世界电信日。) has not been covered by our training data.
# Oops! 富通 (5G板块异动拉升，奥维通信、吴通控股强势封板，亚联发展、富通鑫茂、宜通世纪、汇源通信、吉大通信、中新赛克、法尔胜等均有上涨。消息面，据媒体援引业内人士预计，5G临时牌照有望在本周世界电信日期间发出。5月17日是世界电信日。) has not been covered by our training data.
# Oops! 鑫茂 (5G板块异动拉升，奥维通信、吴通控股强势封板，亚联发展、富通鑫茂、宜通世纪、汇源通信、吉大通信、中新赛克、法尔胜等均有上涨。消息面，据媒体援引业内人士预计，5G临时牌照有望在本周世界电信日期间发出。5月17日是世界电信日。) has not been covered by our training data.
# Oops! 吉大 (5G板块异动拉升，奥维通信、吴通控股强势封板，亚联发展、富通鑫茂、宜通世纪、汇源通信、吉大通信、中新赛克、法尔胜等均有上涨。消息面，据媒体援引业内人士预计，5G临时牌照有望在本周世界电信日期间发出。5月17日是世界电信日。) has not been covered by our training data.
# Oops! 赛克 (5G板块异动拉升，奥维通信、吴通控股强势封板，亚联发展、富通鑫茂、宜通世纪、汇源通信、吉大通信、中新赛克、法尔胜等均有上涨。消息面，据媒体援引业内人士预计，5G临时牌照有望在本周世界电信日期间发出。5月17日是世界电信日。) has not been covered by our training data.
# Oops! 台股 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 及鸿海 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 台股 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 元大 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 投信 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 称三大 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 重鸿海 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 有支 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 调升 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 调升 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 鸿海调 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 降后 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 台股 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 鸿海跌 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 台股 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 及鸿海 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 台股 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 元大 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 投信 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 称三大 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 重鸿海 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 有支 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 调升 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 调升 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 鸿海调 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 降后 (【台股迈向逾七个月来最长日连跌记录 鸿海跌1.8% MSCI调降台股及鸿海权重】台股加权指数下跌0.4%，五日连跌，迈向2018年10月以来最长连跌纪录，鸿海等其他电子类表现最差，其中鸿海下跌1.8%。元大投信称MSCI三大指数同步调降台股权重，鸿海在MSCI台湾指数中的权重调降最大。在MSCI台湾指数成分股中，没有新增或删除成份股，有11支成份股调整在外流通股数，本次权重调升最多的为台积电，调升后权重为35.5%；调降最多的为鸿海，调降后权重为5.96%。) has not been covered by our training data.
# Oops! 优衣库 (【优衣库所有者称日本购物网站46万账户遭黑客攻击】据彭博，亚洲最大的零售商迅销表示，黑客可能已经获取了旗下优衣库和GU品牌电子商务门户网站大约50万用户的个人信息。该公司周一发布声明称，黑客访问了在迅销的日本购物网站上注册的至少46万个账户。总部位于东京的迅销表示，可能已经获取了用户的个人信息、购买历史记录和部分信用卡号码。黑客攻击发生在4月23日至5月10日，公司仍在调查之中。) has not been covered by our training data.
# Oops! 迅销 (【优衣库所有者称日本购物网站46万账户遭黑客攻击】据彭博，亚洲最大的零售商迅销表示，黑客可能已经获取了旗下优衣库和GU品牌电子商务门户网站大约50万用户的个人信息。该公司周一发布声明称，黑客访问了在迅销的日本购物网站上注册的至少46万个账户。总部位于东京的迅销表示，可能已经获取了用户的个人信息、购买历史记录和部分信用卡号码。黑客攻击发生在4月23日至5月10日，公司仍在调查之中。) has not been covered by our training data.
# Oops! 优衣库 (【优衣库所有者称日本购物网站46万账户遭黑客攻击】据彭博，亚洲最大的零售商迅销表示，黑客可能已经获取了旗下优衣库和GU品牌电子商务门户网站大约50万用户的个人信息。该公司周一发布声明称，黑客访问了在迅销的日本购物网站上注册的至少46万个账户。总部位于东京的迅销表示，可能已经获取了用户的个人信息、购买历史记录和部分信用卡号码。黑客攻击发生在4月23日至5月10日，公司仍在调查之中。) has not been covered by our training data.
# Oops! 北方网 ( 【雄安站建设提速 将引入津保京雄石等4条线路】雄安站自去年12月1日进场施工以来，始终提速提质加紧建设。铁路部门相关负责人表示，目前全线施工组织总体顺畅，质量安全有序可控，全线路基工程已完成40%，桥梁工程已完成60%，隧道工程已完成76%。按照规划，雄安站未来将引入津保铁路、京雄石城际铁路、京港台高铁、津忻雄高铁四条线路，实现雄安新区与北京、天津、石家庄等京津冀主要城市的快速联系。（北方网）) has not been covered by our training data.
# Oops! 股逆市 (临近午盘，军工股逆市走强，航天通信封涨停，航天长峰、航天科技、航天电子、航天动力等多只个股拉升。) has not been covered by our training data.
# Oops! 长峰 (临近午盘，军工股逆市走强，航天通信封涨停，航天长峰、航天科技、航天电子、航天动力等多只个股拉升。) has not been covered by our training data.
# Oops! 股逆市 (临近午盘，军工股逆市走强，航天通信封涨停，航天长峰、航天科技、航天电子、航天动力等多只个股拉升。) has not been covered by our training data.
# Oops! 长峰 (临近午盘，军工股逆市走强，航天通信封涨停，航天长峰、航天科技、航天电子、航天动力等多只个股拉升。) has not been covered by our training data.
# Oops! 两部 ( 【华为打通全球首个5G语音+视频VoNR通话】在IMT-2020(5G) 推进组组织的中国5G增强技术研发试验中，华为使用Mate 20X 5G版手机，打通了全球首个5G SA网络下的VoNR通话，包括语音和视频。VoNR是5GSA网络架构下的基本语音解决方案，本次通话基于IMT-2020（5G）推进组统一组织下华为搭建的5G网络，两部手机所在地相距超过60公里。) has not been covered by our training data.
# Oops! 相距 ( 【华为打通全球首个5G语音+视频VoNR通话】在IMT-2020(5G) 推进组组织的中国5G增强技术研发试验中，华为使用Mate 20X 5G版手机，打通了全球首个5G SA网络下的VoNR通话，包括语音和视频。VoNR是5GSA网络架构下的基本语音解决方案，本次通话基于IMT-2020（5G）推进组统一组织下华为搭建的5G网络，两部手机所在地相距超过60公里。) has not been covered by our training data.
# Oops! 两部 ( 【华为打通全球首个5G语音+视频VoNR通话】在IMT-2020(5G) 推进组组织的中国5G增强技术研发试验中，华为使用Mate 20X 5G版手机，打通了全球首个5G SA网络下的VoNR通话，包括语音和视频。VoNR是5GSA网络架构下的基本语音解决方案，本次通话基于IMT-2020（5G）推进组统一组织下华为搭建的5G网络，两部手机所在地相距超过60公里。) has not been covered by our training data.
# Oops! 相距 ( 【华为打通全球首个5G语音+视频VoNR通话】在IMT-2020(5G) 推进组组织的中国5G增强技术研发试验中，华为使用Mate 20X 5G版手机，打通了全球首个5G SA网络下的VoNR通话，包括语音和视频。VoNR是5GSA网络架构下的基本语音解决方案，本次通话基于IMT-2020（5G）推进组统一组织下华为搭建的5G网络，两部手机所在地相距超过60公里。) has not been covered by our training data.
# Oops! 其星链 (【马斯克的星链计划点火测试已经完成 60颗卫星将于15日升空】SpaceX在推特上宣布其星链计划静态点火测试已经完成。根据计划，5月15日，60颗SpaceX星链计划卫星将于佛罗里达州佛州卡纳维拉尔角40号发射位发射升空。) has not been covered by our training data.
# Oops! 日颗 (【马斯克的星链计划点火测试已经完成 60颗卫星将于15日升空】SpaceX在推特上宣布其星链计划静态点火测试已经完成。根据计划，5月15日，60颗SpaceX星链计划卫星将于佛罗里达州佛州卡纳维拉尔角40号发射位发射升空。) has not been covered by our training data.
# Oops! 史进 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 钟胜 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 给史 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 使史 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 史进 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 或致 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 钟胜 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 史进 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 钟胜 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 给史 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 使史 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 史进 (【腾邦国际：控股股东及实控人拟委托表决权 或致公司控制权变化】腾邦国际公告，为优化上市公司治理结构，公司控股股东腾邦集团及公司实控人钟百胜，与史进签订《表决权委托框架协议》，腾邦集团、钟百胜拟将合计持有的公司28.87%股份的表决权委托给史进行使。史进现任腾邦国际控股子公司腾邦旅游集团董事、总经理。后续表决权委托正式协议的签署可能将导致公司控制权的变化，史进可能将成为公司第一大股东。) has not been covered by our training data.
# Oops! 涨逾菜 (夜盘期货开盘，铁矿、焦煤、橡胶、焦炭、玻璃涨逾1%，菜粕、豆粕涨近1%。) has not been covered by our training data.
# Oops! 涨逾菜 (夜盘期货开盘，铁矿、焦煤、橡胶、焦炭、玻璃涨逾1%，菜粕、豆粕涨近1%。) has not been covered by our training data.
# Oops! 预算案 (意大利总统对该国如何制定2020年预算案愈发担忧，如果政府垮台，且没有替代议会多数，最快可能在9月举行大选。（彭博）) has not been covered by our training data.
# Oops! 垮台 (意大利总统对该国如何制定2020年预算案愈发担忧，如果政府垮台，且没有替代议会多数，最快可能在9月举行大选。（彭博）) has not been covered by our training data.
# Oops! 预算案 (意大利总统对该国如何制定2020年预算案愈发担忧，如果政府垮台，且没有替代议会多数，最快可能在9月举行大选。（彭博）) has not been covered by our training data.
# Oops! 垮台 (意大利总统对该国如何制定2020年预算案愈发担忧，如果政府垮台，且没有替代议会多数，最快可能在9月举行大选。（彭博）) has not been covered by our training data.
# Oops! 今赴 (【上海经信委主任吴金城今赴华为公司上海研究所调研】吴金城表示，希望华为公司优化5G产品的工业设计，加强与运营商工作衔接，加强重点区域的覆盖，服务好国际进口博览会、世界人工智能大会等重要活动，提高5G通信的集中度和显示度；立足用户体验，找准商业模式，加大应用场景推进力度，进一步探索智能化的解决方案，凸显5G应用特色，推进上海智慧城市建设能级的再提升。) has not been covered by our training data.
# Oops! 找准 (【上海经信委主任吴金城今赴华为公司上海研究所调研】吴金城表示，希望华为公司优化5G产品的工业设计，加强与运营商工作衔接，加强重点区域的覆盖，服务好国际进口博览会、世界人工智能大会等重要活动，提高5G通信的集中度和显示度；立足用户体验，找准商业模式，加大应用场景推进力度，进一步探索智能化的解决方案，凸显5G应用特色，推进上海智慧城市建设能级的再提升。) has not been covered by our training data.
# Oops! 今赴 (【上海经信委主任吴金城今赴华为公司上海研究所调研】吴金城表示，希望华为公司优化5G产品的工业设计，加强与运营商工作衔接，加强重点区域的覆盖，服务好国际进口博览会、世界人工智能大会等重要活动，提高5G通信的集中度和显示度；立足用户体验，找准商业模式，加大应用场景推进力度，进一步探索智能化的解决方案，凸显5G应用特色，推进上海智慧城市建设能级的再提升。) has not been covered by our training data.
# Oops! 找准 (【上海经信委主任吴金城今赴华为公司上海研究所调研】吴金城表示，希望华为公司优化5G产品的工业设计，加强与运营商工作衔接，加强重点区域的覆盖，服务好国际进口博览会、世界人工智能大会等重要活动，提高5G通信的集中度和显示度；立足用户体验，找准商业模式，加大应用场景推进力度，进一步探索智能化的解决方案，凸显5G应用特色，推进上海智慧城市建设能级的再提升。) has not been covered by our training data.
# Oops! 港版 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 熔断 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 初步阶段 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 向业界 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 熔断 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 鳄 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 提款机 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 防患于未然 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 微结构 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 初步阶段 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 港版 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 熔断 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 初步阶段 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 向业界 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 熔断 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 鳄 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 提款机 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 防患于未然 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 微结构 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# Oops! 初步阶段 (【港交所回应港版“熔断机制”：目前尚处非常初步阶段】今日有市场消息称，港交所正初步向业界咨询有关“熔断机制”的意见，主要为避免香港沦为“大鳄提款机”，防患于未然。对此，证券时报记者向港交所求证，港交所回应称，正与业界探讨各项完善市场微结构的措施，不过目前都处于非常初步的阶段。（证券时报网）) has not been covered by our training data.
# 正确率: 重点信息被关注: 0.856, 无关信息被忽略: 0.692, 错误率： 重点信息被忽略: 0.144, 无关信息被关注: 0.308.
# Gender Testing finished. Duration 1.17 seconds.
